# %%
from lerobot.common.policies.pi0.modeling_pi0 import PI0Policy

policy = PI0Policy.from_pretrained("lerobot/pi0")

# default cache dir is ~/.cache/huggingface/hub
# Out:
# cache dir None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from lerobot.common.policies.pi0.modeling_pi0 import PI0Policy
# ----> 3 policy = PI0Policy.from_pretrained("lerobot/pi0")
#       5 # default cache dir is ~/.cache/huggingface/hub
#
# File ~/code/*/lerobot/lerobot/common/policies/pretrained.py:98, in PreTrainedPolicy.from_pretrained(cls, pretrained_name_or_path, config, force_download, resume_download, proxies, token, cache_dir, local_files_only, revision, map_location, strict, **kwargs)
#      96 print("cache dir", cache_dir)
#      97 model_id = str(pretrained_name_or_path)
# ---> 98 instance = cls(config, **kwargs)
#      99 if os.path.isdir(model_id):
#     100     print("Loading weights from local directory")
#
# ...

# %%
policy
# Out:
# PI0Policy(
#   (normalize_inputs): Normalize()
#   (normalize_targets): Normalize()
#   (unnormalize_outputs): Unnormalize()
#   (model): PI0FlowMatching(
#     (paligemma_with_expert): PaliGemmaWithExpertModel(
#       (paligemma): PaliGemmaForConditionalGeneration(
#         (vision_tower): SiglipVisionModel(
#           (vision_model): SiglipVisionTransformer(
#             (embeddings): SiglipVisionEmbeddings(
#               (patch_embedding): Conv2d(3, 1152, kernel_size=(14, 14), stride=(14, 14), padding=valid)
#               (position_embedding): Embedding(256, 1152)
#             )
#             (encoder): SiglipEncoder(
#               (layers): ModuleList(
#                 (0-26): 27 x SiglipEncoderLayer(
#                   (self_attn): SiglipSdpaAttention(
#                     (k_proj): Linear(in_features=1152, out_features=1152, bias=True)
#                     (v_proj): Linear(in_features=1152, out_features=1152, bias=True)
# ...

# %%
action = policy.select_action(batch)
